# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./Data/Elevator_Patents_List.CSV")

# %%
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252047 entries, 0 to 252046
# Data columns (total 51 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   标题         252047 non-null  object
#  1   产业链位置      252047 non-null  object
#  2   一级技术分支     252047 non-null  object
#  3   二级技术分支     252047 non-null  object
#  4   三级技术分支     252047 non-null  object
#  5   申请号        252047 non-null  object
#  6   申请日        252047 non-null  object
#  7   申请人        252047 non-null  object
#  8   专利类型       252047 non-null  object
#  9   公开国别       252047 non-null  object
#  10  公开(公告)号    252047 non-null  object
#  11  公开(公告)日    252047 non-null  object
#  12  权利要求数量     252032 non-null  object
#  13  文献页数       252046 non-null  object
#  14  技术功效       252047 non-null  object
#  15  IPC        252047 non-null  object
#  16  标准化申请人     252047 non-null  object
#  17  申请人国别代码    252040 non-null  object
#  18  申请人省市代码    252047 non-null  object
# ...

# %%
df=df.replace({"-":np.nan})

# %%
df.rename(columns={"产业链位置":"Industry Chain Position","一级技术分支":"Primary Technical Branch","专利类型":"Patent Type","公开国别":"Publication Country","公开(公告)日":"Publication Date","权利要求数量":"Number of Claims","文献页数":"Number of Document Pages","IPC":"IPC","申请人省市代码":"Applicant's Province and City Code","3年内被引用次数":"Number of Citations within 3 Years","5年内被引用次数":"Number of Citations within 5 Years","引用专利数量":"Number of Citing Patents","被引用专利数量":"Number of Cited Patents","专利有效性":"Patent Validity","诉讼案件数":"Number of Litigation Cases","专利价值":"Patent Value"
}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252047 entries, 0 to 252046
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   标题                                  251906 non-null  object
#  1   Industry Chain Position             252047 non-null  object
#  2   Primary Technical Branch            252047 non-null  object
#  3   二级技术分支                              252047 non-null  object
#  4   三级技术分支                              252047 non-null  object
#  5   申请号                                 251825 non-null  object
#  6   申请日                                 251599 non-null  object
#  7   申请人                                 250945 non-null  object
#  8   Patent Type                         252047 non-null  object
#  9   Publication Country                 252047 non-null  object
#  10  公开(公告)号                             252047 non-null  object
# ...

# %%
# columns_to_drop=["申请号","申请人","标准化申请人","转让人","受让人","被许可人","许可人","审查员","助理审查员","审判长","审判员","申请人国别代码","申请人地市","申请人区县","申请人地址","代理机构","代理人","简单同族","INPADOC同族","质押人","质权人","原告(上诉人)","被告(被上诉人)","法院","IPC","公开(公告)号","优先权号","优先权日","许可类型","技术功效","优先权国家","二级技术分支","三级技术分支","专利寿命","申请日"]
# df.drop(columns=columns_to_drop,inplace=True)
# df.info()

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#             标题 Industry Chain Position Primary Technical Branch  二级技术分支  \
# count   251906                  252047                   252047  252047
# unique  110328                       3                       12      42
# top     乗客コンベア                   产业链中游                     应用市场    制动模块
# freq       734                  108978                    43022   22645
#
#         三级技术分支               申请号         申请日       申请人 Patent Type  \
# count   252047            251825      251599    250945      252047
# unique      53            157025       18723     32602           4
# top          /  CN201921375852.3  2016-08-31  三菱電機株式会社        实用新型
# freq    123352                11         503      9127       93895
#
#        Publication Country  ...                                       质权人  \
# count               252047  ...                                      1000
# unique                  88  ...                                       257
# ...

# %%
# df.dropna(inplace=True)

# %%
# df = df[~df.apply(lambda row: any(row == "该数据不支持导出"), axis=1)]

# %%
# df["Number of Claims"]=df["Number of Claims"].astype(int)
# df["Number of Document Pages"]=df["Number of Document Pages"].astype(int)
# df["Number of Cited Patents"]=df["Number of Cited Patents"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252047 entries, 0 to 252046
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   标题                                  251906 non-null  object
#  1   Industry Chain Position             252047 non-null  object
#  2   Primary Technical Branch            252047 non-null  object
#  3   二级技术分支                              252047 non-null  object
#  4   三级技术分支                              252047 non-null  object
#  5   申请号                                 251825 non-null  object
#  6   申请日                                 251599 non-null  object
#  7   申请人                                 250945 non-null  object
#  8   Patent Type                         252047 non-null  object
#  9   Publication Country                 252047 non-null  object
#  10  公开(公告)号                             252047 non-null  object
# ...

# %%
replace_dict = {
    "北京": "Beijing",
    "天津": "Tianjin",
    "河北": "Hebei",
    "山西": "Shanxi",
    "内蒙古": "Inner Mongolia",
    "辽宁": "Liaoning",
    "吉林": "Jilin",
    "黑龙江": "Heilongjiang",
    "上海": "Shanghai",
    "江苏": "Jiangsu",
    "浙江": "Zhejiang",
    "安徽": "Anhui",
    "福建": "Fujian",
    "江西": "Jiangxi",
    "山东": "Shandong",
    "河南": "Henan",
    "湖北": "Hubei",
    "湖南": "Hunan",
    "广东": "Guangdong",
    "广西": "Guangxi",
    "海南": "Hainan",
    "重庆": "Chongqing",
    "四川": "Sichuan",
    "贵州": "Guizhou",
    "云南": "Yunnan",
    "西藏": "Tibet",
    "陕西": "Shaanxi",
    "甘肃": "Gansu",
    "青海": "Qinghai",
    "宁夏": "Ningxia",
    "新疆": "Xinjiang",
    "台湾": "Taiwan",
    "香港": "Hong Kong",
    "澳门": "Macao"
}

# %%
df["Applicant's Province and City Code"] = df["Applicant's Province and City Code"].replace(replace_dict)

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#             标题 Industry Chain Position Primary Technical Branch  二级技术分支  \
# count   251906                  252047                   252047  252047
# unique  110328                       3                       12      42
# top     乗客コンベア                   产业链中游                     应用市场    制动模块
# freq       734                  108978                    43022   22645
#
#         三级技术分支               申请号         申请日       申请人 Patent Type  \
# count   252047            251825      251599    250945      252047
# unique      53            157025       18723     32602           4
# top          /  CN201921375852.3  2016-08-31  三菱電機株式会社        实用新型
# freq    123352                11         503      9127       93895
#
#        Publication Country  ...                                       质权人  \
# count               252047  ...                                      1000
# unique                  88  ...                                       257
# ...

# %%
country_replace_dict = {
    "中国": "China",
    "美国": "United States",
    "英国": "United Kingdom",
    "加拿大": "Canada",
    "澳大利亚": "Australia",
    "德国": "Germany",
    "法国": "France",
    "日本": "Japan",
    "韩国":"Korea"
    # 添加其他国家...
}

# %%
df["Publication Country"] = df["Publication Country"].replace(country_replace_dict)

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#             标题 Industry Chain Position Primary Technical Branch  二级技术分支  \
# count   251906                  252047                   252047  252047
# unique  110328                       3                       12      42
# top     乗客コンベア                   产业链中游                     应用市场    制动模块
# freq       734                  108978                    43022   22645
#
#         三级技术分支               申请号         申请日       申请人 Patent Type  \
# count   252047            251825      251599    250945      252047
# unique      53            157025       18723     32602           4
# top          /  CN201921375852.3  2016-08-31  三菱電機株式会社        实用新型
# freq    123352                11         503      9127       93895
#
#        Publication Country  ...                                       质权人  \
# count               252047  ...                                      1000
# unique                  88  ...                                       257
# ...

# %%
chain_replace_dict = {
    "产业链上游": "Upstream",
    "产业链中游": "Midstream",
    "产业链下游": "Downstream",
}
type_replace_dict = {
    "实用新型": "Utility Model Patent",
    "授权发明": "Granted Utility Patent",
    "发明申请": "Invention Patent",
    "外观设计":"Design Patent",
}
Validity_replace_dict = {
    "有效": "Valid",
    "失效": "Invalid",
    "审中": "Pending",
}
Branch_replace_dict = {
    "安全保护系统": "Security Protection System",
    "导向系统": "Guidance system",
    "电力控制系统": "Power control system",
    "电力拖动系统": "Electric Drag System",
    "电梯制造": "Elevator Manufacturing",
    "轿厢系统": "Car Systems",
    "控制系统": "Control system",
    "门系统": "Door System",
    "曳引系统": "Traction system",
    "应用市场": "Application Market",
    "原材料": "Raw material",
    "重量平衡系统": "Weight balancing system"
}

# %%
df["Industry Chain Position"] = df["Industry Chain Position"].replace(chain_replace_dict)

# %%
df["Patent Type"] = df["Patent Type"].replace(type_replace_dict)

# %%
df["Patent Validity"] = df["Patent Validity"].replace(Validity_replace_dict)

# %%
df["Primary Technical Branch"] = df["Primary Technical Branch"].replace(Branch_replace_dict)

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#             标题 Industry Chain Position Primary Technical Branch  二级技术分支  \
# count   251906                  252047                   252047  252047
# unique  110328                       3                       12      42
# top     乗客コンベア               Midstream       Application Market    制动模块
# freq       734                  108978                    43022   22645
#
#         三级技术分支               申请号         申请日       申请人           Patent Type  \
# count   252047            251825      251599    250945                252047
# unique      53            157025       18723     32602                     4
# top          /  CN201921375852.3  2016-08-31  三菱電機株式会社  Utility Model Patent
# freq    123352                11         503      9127                 93895
#
#        Publication Country  ...                                       质权人  \
# count               252047  ...                                      1000
# ...

# %%
# df['Publication Date'] = df['Publication Date'].str[:4]
# df["Publication Date"] = pd.to_numeric(df["Publication Date"])

# %%
# for index,row in df.iterrows():
#     value = row['Patent Value']  # 获取当前行中 "column_name" 属性的值
#     # 在这里对属性值进行操作，例如加倍
#     new_value=value[1:]
#     number = new_value.replace(',', '')
#     # 将操作后的值赋回到当前行的属性
#     df.at[index, 'Patent Value'] = number
# df['Patent Value'] = df['Patent Value'].astype(np.int64)

# %%
df.head(5)
# Out:
#                          标题 Industry Chain Position Primary Technical Branch  \
# 0              铝合金材质轨道的对接结构                Upstream             Raw material
# 1               一种铝合金材质的护壁板                Upstream             Raw material
# 2            一种新型的SUS材质门楣结构                Upstream             Raw material
# 3              铝合金材质的吊顶边框结构                Upstream             Raw material
# 4  电梯安全钳楔块用复合材料、铜增强材料及其制备方法                Upstream             Raw material
#
#   二级技术分支 三级技术分支               申请号         申请日                申请人  \
# 0     基材      /  CN201921346564.5  2019-08-19        幸福树电机股份有限公司
# 1     基材      /  CN201820925382.2  2018-06-14       浙江梅轮电梯股份有限公司
# 2     基材      /  CN202120423575.X  2021-02-26      苏州市世嘉科技股份有限公司
# 3     基材      /  CN202210864929.3  2022-07-21  波士顿(湖州)家用电梯科技有限公司
# 4     基材      /  CN202111071711.4  2021-09-14        西安特种设备检验检测院
#
#             Patent Type Publication Country  ... Number of Litigation Cases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252047 entries, 0 to 252046
# Data columns (total 51 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   标题                                  251906 non-null  object
#  1   Industry Chain Position             252047 non-null  object
#  2   Primary Technical Branch            252047 non-null  object
#  3   二级技术分支                              252047 non-null  object
#  4   三级技术分支                              252047 non-null  object
#  5   申请号                                 251825 non-null  object
#  6   申请日                                 251599 non-null  object
#  7   申请人                                 250945 non-null  object
#  8   Patent Type                         252047 non-null  object
#  9   Publication Country                 252047 non-null  object
#  10  公开(公告)号                             252047 non-null  object
# ...

# %%
# df.to_excel("./Data/rawdata.xlsx",index=False)
df.to_csv("./Data/rawdata.CSV",index=False)
