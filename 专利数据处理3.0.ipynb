# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./Data/Elevator_Patents_List.CSV")

# %%
df.info()
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252047 entries, 0 to 252046
# Data columns (total 51 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   标题         252047 non-null  object
#  1   产业链位置      252047 non-null  object
#  2   一级技术分支     252047 non-null  object
#  3   二级技术分支     252047 non-null  object
#  4   三级技术分支     252047 non-null  object
#  5   申请号        252047 non-null  object
#  6   申请日        252047 non-null  object
#  7   申请人        252047 non-null  object
#  8   专利类型       252047 non-null  object
#  9   公开国别       252047 non-null  object
#  10  公开(公告)号    252047 non-null  object
#  11  公开(公告)日    252047 non-null  object
#  12  权利要求数量     252032 non-null  object
#  13  文献页数       252046 non-null  object
#  14  技术功效       252047 non-null  object
#  15  IPC        252047 non-null  object
#  16  标准化申请人     252047 non-null  object
#  17  申请人国别代码    252040 non-null  object
#  18  申请人省市代码    252047 non-null  object
#  19  申请人地市      252031 non-null  object
#  20  申请人区县      252047 non-null  object
#  21  申请人地址      252033 non-null  object
#  22  代理机构       252047 non-null  object
#  23  代理人        252047 non-null  object
#  24  3年内被引用次数   252047 non-null  int64
#  25  5年内被引用次数   252047 non-null  int64
#  26  引用专利数量     252047 non-null  int64
#  27  被引用专利数量    252045 non-null  float64
#  28  简单同族       252047 non-null  object
#  29  INPADOC同族  252047 non-null  object
#  30  优先权号       252017 non-null  object
#  31  优先权日       252022 non-null  object
#  32  优先权国家      252047 non-null  object
#  33  专利有效性      252047 non-null  object
#  34  转让人        252047 non-null  object
#  35  受让人        252047 non-null  object
#  36  许可人        252047 non-null  object
#  37  被许可人       252047 non-null  object
#  38  许可类型       252047 non-null  object
#  39  质押人        252047 non-null  object
#  40  质权人        252047 non-null  object
#  41  诉讼案件数      252047 non-null  int64
#  42  原告(上诉人)    252047 non-null  object
#  43  被告(被上诉人)   252047 non-null  object
#  44  法院         252047 non-null  object
#  45  审判长        252047 non-null  object
#  46  审判员        252047 non-null  object
#  47  专利价值       252047 non-null  object
#  48  专利寿命       252047 non-null  object
#  49  审查员        252047 non-null  object
#  50  助理审查员      252047 non-null  object
# dtypes: float64(1), int64(4), object(46)
# memory usage: 98.1+ MB
#                          标题  产业链位置 一级技术分支 二级技术分支 三级技术分支               申请号  \
# 0              铝合金材质轨道的对接结构  产业链上游    原材料     基材      /  CN201921346564.5
# 1               一种铝合金材质的护壁板  产业链上游    原材料     基材      /  CN201820925382.2
# 2            一种新型的SUS材质门楣结构  产业链上游    原材料     基材      /  CN202120423575.X
# 3              铝合金材质的吊顶边框结构  产业链上游    原材料     基材      /  CN202210864929.3
# 4  电梯安全钳楔块用复合材料、铜增强材料及其制备方法  产业链上游    原材料     基材      /  CN202111071711.4
#
#           申请日                申请人  专利类型 公开国别  ... 诉讼案件数 原告(上诉人) 被告(被上诉人) 法院  \
# 0  2019-08-19        幸福树电机股份有限公司  实用新型   中国  ...     0       -        -  -
# 1  2018-06-14       浙江梅轮电梯股份有限公司  实用新型   中国  ...     0       -        -  -
# 2  2021-02-26      苏州市世嘉科技股份有限公司  实用新型   中国  ...     0       -        -  -
# 3  2022-07-21  波士顿(湖州)家用电梯科技有限公司  发明申请   中国  ...     0       -        -  -
# 4  2021-09-14        西安特种设备检验检测院  发明申请   中国  ...     0       -        -  -
#
#   审判长 审判员     专利价值        专利寿命 审查员 助理审查员
# 0   -   -  $ 3,300  2029-08-19   -     -
# 1   -   -  $ 3,400  2028-06-14   -     -
# 2   -   -  $ 3,400  2031-02-26   -     -
# 3   -   -        -           -   -     -
# 4   -   -  $ 3,400           -   -     -
#
# [5 rows x 51 columns]

# %%
df=df.replace({"-":np.nan})

# %%
print(df.isnull().sum())
print(df.isnull().any(axis=1).sum())
# Out:
# 标题              141
# 产业链位置             0
# 一级技术分支            0
# 二级技术分支            0
# 三级技术分支            0
# 申请号             222
# 申请日             448
# 申请人            1102
# 专利类型              0
# 公开国别              0
# 公开(公告)号           0
# 公开(公告)日          75
# 权利要求数量        31134
# 文献页数           6955
# 技术功效          91751
# IPC            9898
# 标准化申请人         1266
# 申请人国别代码       20096
# 申请人省市代码       43830
# 申请人地市         48612
# 申请人区县        116162
# 申请人地址         17554
# 代理机构         115362
# 代理人           82906
# 3年内被引用次数          0
# 5年内被引用次数          0
# 引用专利数量            0
# 被引用专利数量           2
# 简单同族              0
# INPADOC同族        95
# 优先权号         211119
# 优先权日         211114
# 优先权国家        211089
# 专利有效性             0
# 转让人            1102
# 受让人            1102
# 许可人          251301
# 被许可人         251301
# 许可类型         251301
# 质押人          251047
# 质权人          251047
# 诉讼案件数             0
# 原告(上诉人)      251820
# 被告(被上诉人)     251832
# 法院           251818
# 审判长          251897
# 审判员          251869
# 专利价值         150842
# 专利寿命          73992
# 审查员          213900
# 助理审查员        249570
# dtype: int64
# 252047

# %%
df = df.dropna(subset=['专利价值'])

# %%
print(df.isnull().sum())
# Out:
# 标题                0
# 产业链位置             0
# 一级技术分支            0
# 二级技术分支            0
# 三级技术分支            0
# 申请号               0
# 申请日               2
# 申请人              23
# 专利类型              0
# 公开国别              0
# 公开(公告)号           0
# 公开(公告)日           0
# 权利要求数量         3331
# 文献页数           3249
# 技术功效          21099
# IPC               0
# 标准化申请人           47
# 申请人国别代码        1302
# 申请人省市代码        8213
# 申请人地市         10635
# 申请人区县         29683
# 申请人地址           579
# 代理机构          25594
# 代理人           25536
# 3年内被引用次数          0
# 5年内被引用次数          0
# 引用专利数量            0
# 被引用专利数量           0
# 简单同族              0
# INPADOC同族        47
# 优先权号          88988
# 优先权日          88983
# 优先权国家         88969
# 专利有效性             0
# 转让人              23
# 受让人              23
# 许可人          100934
# 被许可人         100934
# 许可类型         100934
# 质押人          100436
# 质权人          100436
# 诉讼案件数             0
# 原告(上诉人)      101161
# 被告(被上诉人)     101161
# 法院           101160
# 审判长          101165
# 审判员          101169
# 专利价值              0
# 专利寿命          17467
# 审查员           78298
# 助理审查员        100825
# dtype: int64

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#             标题   产业链位置  一级技术分支  二级技术分支  三级技术分支               申请号         申请日  \
# count   101205  101205  101205  101205  101205            101205      101203
# unique   46845       3      12      42      53             57817        5125
# top     乗客コンベア   产业链中游    应用市场    制动模块       /  CN201921375852.3  2020-12-31
# freq       301   41530   21697    9383   50214                11         231
#
#                           申请人    专利类型    公开国别  ...  \
# count                  101182  101205  101205  ...
# unique                  11861       3      63  ...
# top     OTIS ELEVATOR COMPANY    实用新型      中国  ...
# freq                     2267   51407   79697  ...
#
#                                              质权人  \
# count                                        769
# unique                                       190
# top     1.天津市东方海鑫中小企业担保有限公司\n2.天津市东方海鑫中小企业担保有限公司
# freq                                          33
#
#                              原告(上诉人)            被告(被上诉人)            法院  审判长  \
# count                             44                  44            45   40
# unique                            17                  17            16   13
# top     1.杨旭\n2.窦伯英\n3.洛阳泰斯特探伤技术有限公司  1.洛阳逖悉开钢丝绳检测技术有限公司  河南省洛阳市中级人民法院  邱平平
# freq                              19                  19            19   19
#
#                   审判员     专利价值        专利寿命    审查员          助理审查员
# count              36   101205       83738  22907            380
# unique             12      445        5908    565             77
# top     ["赵广云","杨元卿"]  $ 3,400  2030-12-31    ???  KRUER, STEFAN
# freq               19    31727         185    902            110
#
# [4 rows x 46 columns]

# %%
#删除无用信息
columns_to_drop=["申请号","申请人","标准化申请人","转让人","受让人","被许可人","许可人","审查员","助理审查员","审判长","审判员","申请人国别代码","申请人地市","申请人区县","申请人地址","代理机构","代理人","简单同族","INPADOC同族","质押人","质权人","原告(上诉人)","被告(被上诉人)","法院","公开(公告)号","优先权号","优先权日","许可类型","技术功效","优先权国家","二级技术分支","三级技术分支","专利寿命","申请日"]
df.drop(columns=columns_to_drop,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 101205 entries, 0 to 251889
# Data columns (total 17 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   标题        101205 non-null  object
#  1   产业链位置     101205 non-null  object
#  2   一级技术分支    101205 non-null  object
#  3   专利类型      101205 non-null  object
#  4   公开国别      101205 non-null  object
#  5   公开(公告)日   101205 non-null  object
#  6   权利要求数量    97874 non-null   object
#  7   文献页数      97956 non-null   object
#  8   IPC       101205 non-null  object
#  9   申请人省市代码   92992 non-null   object
#  10  3年内被引用次数  101205 non-null  int64
#  11  5年内被引用次数  101205 non-null  int64
#  12  引用专利数量    101205 non-null  int64
#  13  被引用专利数量   101205 non-null  float64
#  14  专利有效性     101205 non-null  object
#  15  诉讼案件数     101205 non-null  int64
#  16  专利价值      101205 non-null  object
# dtypes: float64(1), int64(4), object(12)
# memory usage: 13.9+ MB

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 标题          0
# 产业链位置       0
# 一级技术分支      0
# 专利类型        0
# 公开国别        0
# 公开(公告)日     0
# 权利要求数量      0
# 文献页数        0
# IPC         0
# 申请人省市代码     0
# 3年内被引用次数    0
# 5年内被引用次数    0
# 引用专利数量      0
# 被引用专利数量     0
# 专利有效性       0
# 诉讼案件数       0
# 专利价值        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89399 entries, 0 to 251889
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   标题        89399 non-null  object
#  1   产业链位置     89399 non-null  object
#  2   一级技术分支    89399 non-null  object
#  3   专利类型      89399 non-null  object
#  4   公开国别      89399 non-null  object
#  5   公开(公告)日   89399 non-null  object
#  6   权利要求数量    89399 non-null  object
#  7   文献页数      89399 non-null  object
#  8   IPC       89399 non-null  object
#  9   申请人省市代码   89399 non-null  object
#  10  3年内被引用次数  89399 non-null  int64
#  11  5年内被引用次数  89399 non-null  int64
#  12  引用专利数量    89399 non-null  int64
#  13  被引用专利数量   89399 non-null  float64
#  14  专利有效性     89399 non-null  object
#  15  诉讼案件数     89399 non-null  int64
#  16  专利价值      89399 non-null  object
# dtypes: float64(1), int64(4), object(12)
# memory usage: 12.3+ MB

# %%
df.head(5)
# Out:
#                           标题  产业链位置 一级技术分支  专利类型 公开国别     公开(公告)日 权利要求数量 文献页数  \
# 0               铝合金材质轨道的对接结构  产业链上游    原材料  实用新型   中国  2020-07-03      7   15
# 1                一种铝合金材质的护壁板  产业链上游    原材料  实用新型   中国  2019-01-04      4    7
# 2             一种新型的SUS材质门楣结构  产业链上游    原材料  实用新型   中国  2021-12-21      5    5
# 4   电梯安全钳楔块用复合材料、铜增强材料及其制备方法  产业链上游    原材料  发明申请   中国  2021-12-31     10   16
# 11          一种新型轻质材料电梯轿厢减震底板  产业链上游    原材料  实用新型   中国  2019-11-01     10    6
#
#                                                   IPC 申请人省市代码  3年内被引用次数  \
# 0                                 B66B7/02 | F16B7/18      TW         0
# 1                               B66B23/22 | B66B23/24      浙江         0
# 2                                           B66B13/30      江苏         0
# 4          B66B5/22 | B66B5/24 | B22D17/14 | C22C9/04      陕西         0
# 11  B66B11/02 | F16F15/04 | F16F15/08 | B32B15/08 ...      浙江         0
#
#     5年内被引用次数  引用专利数量  被引用专利数量 专利有效性  诉讼案件数     专利价值
# 0          0       0      0.0    有效      0  $ 3,300
# 1          0       0      0.0    有效      0  $ 3,400
# 2          0       0      0.0    有效      0  $ 3,400
# 4          0       0      0.0    审中      0  $ 3,400
# 11         0       1      0.0    有效      0  $ 3,400

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#             标题  产业链位置 一级技术分支   专利类型   公开国别     公开(公告)日 权利要求数量   文献页数  \
# count    89399  89399  89399  89399  89399       89399  89399  89399
# unique   40713      3     12      3     26        2909     62     95
# top     乗客コンベア  产业链中游   应用市场   实用新型     中国  2021-10-22      6      7
# freq       290  36261  20847  49439  76477         320  14511  13218
#
#               IPC 申请人省市代码  专利有效性     专利价值
# count       89399   89399  89399    89399
# unique      14481     325      5      400
# top     B66B11/02      江苏     有效  $ 3,400
# freq         3769   17161  72768    30769

# %%
df.isnull().sum()
# Out:
# 标题          0
# 产业链位置       0
# 一级技术分支      0
# 专利类型        0
# 公开国别        0
# 公开(公告)日     0
# 权利要求数量      0
# 文献页数        0
# IPC         0
# 申请人省市代码     0
# 3年内被引用次数    0
# 5年内被引用次数    0
# 引用专利数量      0
# 被引用专利数量     0
# 专利有效性       0
# 诉讼案件数       0
# 专利价值        0
# dtype: int64

# %%
df=df.loc[df["公开国别"]=="中国"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76477 entries, 0 to 251889
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   标题        76477 non-null  object
#  1   产业链位置     76477 non-null  object
#  2   一级技术分支    76477 non-null  object
#  3   专利类型      76477 non-null  object
#  4   公开国别      76477 non-null  object
#  5   公开(公告)日   76477 non-null  object
#  6   权利要求数量    76477 non-null  object
#  7   文献页数      76477 non-null  object
#  8   IPC       76477 non-null  object
#  9   申请人省市代码   76477 non-null  object
#  10  3年内被引用次数  76477 non-null  int64
#  11  5年内被引用次数  76477 non-null  int64
#  12  引用专利数量    76477 non-null  int64
#  13  被引用专利数量   76477 non-null  float64
#  14  专利有效性     76477 non-null  object
#  15  诉讼案件数     76477 non-null  int64
#  16  专利价值      76477 non-null  object
# dtypes: float64(1), int64(4), object(12)
# memory usage: 10.5+ MB

# %%
df.head(5)
# Out:
#                           标题  产业链位置 一级技术分支  专利类型 公开国别     公开(公告)日 权利要求数量 文献页数  \
# 0               铝合金材质轨道的对接结构  产业链上游    原材料  实用新型   中国  2020-07-03      7   15
# 1                一种铝合金材质的护壁板  产业链上游    原材料  实用新型   中国  2019-01-04      4    7
# 2             一种新型的SUS材质门楣结构  产业链上游    原材料  实用新型   中国  2021-12-21      5    5
# 4   电梯安全钳楔块用复合材料、铜增强材料及其制备方法  产业链上游    原材料  发明申请   中国  2021-12-31     10   16
# 11          一种新型轻质材料电梯轿厢减震底板  产业链上游    原材料  实用新型   中国  2019-11-01     10    6
#
#                                                   IPC 申请人省市代码  3年内被引用次数  \
# 0                                 B66B7/02 | F16B7/18      TW         0
# 1                               B66B23/22 | B66B23/24      浙江         0
# 2                                           B66B13/30      江苏         0
# 4          B66B5/22 | B66B5/24 | B22D17/14 | C22C9/04      陕西         0
# 11  B66B11/02 | F16F15/04 | F16F15/08 | B32B15/08 ...      浙江         0
#
#     5年内被引用次数  引用专利数量  被引用专利数量 专利有效性  诉讼案件数     专利价值
# 0          0       0      0.0    有效      0  $ 3,300
# 1          0       0      0.0    有效      0  $ 3,400
# 2          0       0      0.0    有效      0  $ 3,400
# 4          0       0      0.0    审中      0  $ 3,400
# 11         0       1      0.0    有效      0  $ 3,400

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#            标题  产业链位置 一级技术分支   专利类型   公开国别     公开(公告)日 权利要求数量   文献页数  \
# count   76477  76477  76477  76477  76477       76477  76477  76477
# unique  34129      3     12      3      1        1022     52     63
# top      电梯装置  产业链中游   应用市场   实用新型     中国  2021-10-22      6      7
# freq      151  28946  20124  49253  76477         320  13411  12647
#
#               IPC 申请人省市代码  专利有效性     专利价值
# count       76477   76477  76477    76477
# unique      11637     112      3      318
# top     B66B11/02      江苏     有效  $ 3,400
# freq         3592   17087  61888    30722

# %%
df = df[~df.apply(lambda row: any(row == "该数据不支持导出"), axis=1)]

# %%
df["权利要求数量"]=df["权利要求数量"].astype(int)
df["文献页数"]=df["文献页数"].astype(int)
df["被引用专利数量"]=df["被引用专利数量"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76477 entries, 0 to 251889
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   标题        76477 non-null  object
#  1   产业链位置     76477 non-null  object
#  2   一级技术分支    76477 non-null  object
#  3   专利类型      76477 non-null  object
#  4   公开国别      76477 non-null  object
#  5   公开(公告)日   76477 non-null  object
#  6   权利要求数量    76477 non-null  int32
#  7   文献页数      76477 non-null  int32
#  8   IPC       76477 non-null  object
#  9   申请人省市代码   76477 non-null  object
#  10  3年内被引用次数  76477 non-null  int64
#  11  5年内被引用次数  76477 non-null  int64
#  12  引用专利数量    76477 non-null  int64
#  13  被引用专利数量   76477 non-null  int32
#  14  专利有效性     76477 non-null  object
#  15  诉讼案件数     76477 non-null  int64
#  16  专利价值      76477 non-null  object
# dtypes: int32(3), int64(4), object(10)
# memory usage: 9.6+ MB

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#            标题  产业链位置 一级技术分支   专利类型   公开国别     公开(公告)日        IPC 申请人省市代码  \
# count   76477  76477  76477  76477  76477       76477      76477   76477
# unique  34129      3     12      3      1        1022      11637     112
# top      电梯装置  产业链中游   应用市场   实用新型     中国  2021-10-22  B66B11/02      江苏
# freq      151  28946  20124  49253  76477         320       3592   17087
#
#         专利有效性     专利价值
# count   76477    76477
# unique      3      318
# top        有效  $ 3,400
# freq    61888    30722

# %%
china_provinces = ["河北","山西","黑龙江","吉林","辽宁","江苏","浙江","安徽","福建","江西","山东","河南","湖北","湖南","广东","海南","四川","贵州","云南","陕西","甘肃","青海","台湾","内蒙古","广西","西藏","宁夏","新疆","北京","天津","上海","重庆","香港","澳门"]  # 包含中国各个省份的列表
df = df[df['申请人省市代码'].isin(china_provinces)]

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#            标题  产业链位置 一级技术分支   专利类型   公开国别     公开(公告)日        IPC 申请人省市代码  \
# count   72037  72037  72037  72037  72037       72037      72037   72037
# unique  31951      3     12      3      1         924      10865      31
# top      一种电梯  产业链中游   应用市场   实用新型     中国  2021-12-03  B66B11/02      江苏
# freq       72  26566  19435  48844  72037         313       3514   17087
#
#         专利有效性     专利价值
# count   72037    72037
# unique      3      167
# top        有效  $ 3,400
# freq    58248    30630

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72037 entries, 1 to 251889
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   标题        72037 non-null  object
#  1   产业链位置     72037 non-null  object
#  2   一级技术分支    72037 non-null  object
#  3   专利类型      72037 non-null  object
#  4   公开国别      72037 non-null  object
#  5   公开(公告)日   72037 non-null  object
#  6   权利要求数量    72037 non-null  int32
#  7   文献页数      72037 non-null  int32
#  8   IPC       72037 non-null  object
#  9   申请人省市代码   72037 non-null  object
#  10  3年内被引用次数  72037 non-null  int64
#  11  5年内被引用次数  72037 non-null  int64
#  12  引用专利数量    72037 non-null  int64
#  13  被引用专利数量   72037 non-null  int32
#  14  专利有效性     72037 non-null  object
#  15  诉讼案件数     72037 non-null  int64
#  16  专利价值      72037 non-null  object
# dtypes: int32(3), int64(4), object(10)
# memory usage: 9.1+ MB

# %%
for index,row in df.iterrows():
    value = row['专利价值']  # 获取当前行中 "column_name" 属性的值
    # 在这里对属性值进行操作，例如加倍
    new_value=value[1:]
    number = new_value.replace(',', '')
    # 将操作后的值赋回到当前行的属性
    df.at[index, '专利价值'] = number
df['专利价值'] = df['专利价值'].astype(np.int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72037 entries, 1 to 251889
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   标题        72037 non-null  object
#  1   产业链位置     72037 non-null  object
#  2   一级技术分支    72037 non-null  object
#  3   专利类型      72037 non-null  object
#  4   公开国别      72037 non-null  object
#  5   公开(公告)日   72037 non-null  object
#  6   权利要求数量    72037 non-null  int32
#  7   文献页数      72037 non-null  int32
#  8   IPC       72037 non-null  object
#  9   申请人省市代码   72037 non-null  object
#  10  3年内被引用次数  72037 non-null  int64
#  11  5年内被引用次数  72037 non-null  int64
#  12  引用专利数量    72037 non-null  int64
#  13  被引用专利数量   72037 non-null  int32
#  14  专利有效性     72037 non-null  object
#  15  诉讼案件数     72037 non-null  int64
#  16  专利价值      72037 non-null  int64
# dtypes: int32(3), int64(5), object(9)
# memory usage: 11.1+ MB

# %%
df['公开(公告)日'] = df['公开(公告)日'].str[:4]
df["公开(公告)日"] = pd.to_numeric(df["公开(公告)日"])

# %%
# df["专利价值（对数变换）"]=np.log(df["专利价值"])

# %%
df["IPC"]=df["IPC"].map(lambda x: x.replace(" ","").split('|')[0].split("/")[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72037 entries, 1 to 251889
# Data columns (total 17 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   标题        72037 non-null  object
#  1   产业链位置     72037 non-null  object
#  2   一级技术分支    72037 non-null  object
#  3   专利类型      72037 non-null  object
#  4   公开国别      72037 non-null  object
#  5   公开(公告)日   72037 non-null  int64
#  6   权利要求数量    72037 non-null  int32
#  7   文献页数      72037 non-null  int32
#  8   IPC       72037 non-null  object
#  9   申请人省市代码   72037 non-null  object
#  10  3年内被引用次数  72037 non-null  int64
#  11  5年内被引用次数  72037 non-null  int64
#  12  引用专利数量    72037 non-null  int64
#  13  被引用专利数量   72037 non-null  int32
#  14  专利有效性     72037 non-null  object
#  15  诉讼案件数     72037 non-null  int64
#  16  专利价值      72037 non-null  int64
# dtypes: int32(3), int64(6), object(8)
# memory usage: 11.1+ MB

# %%
df.select_dtypes(include=["object"]).describe()
# Out:
#            标题  产业链位置 一级技术分支   专利类型   公开国别    IPC 申请人省市代码  专利有效性
# count   72037  72037  72037  72037  72037  72037   72037  72037
# unique  31951      3     12      3      1     15      31      3
# top      一种电梯  产业链中游   应用市场   实用新型     中国  B66B5      江苏     有效
# freq       72  26566  19435  48844  72037  19687   17087  58248

# %%
df["专利价值分类"]="大"
df.loc[df["专利价值"]<10000,"专利价值分类"]="小"

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.use('TkAgg')
# plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用中文黑体字体

# 筛选出数值属性列
numeric_cols = df.select_dtypes(include=['int', 'float']).columns

# 计算相关性矩阵，并绘制热力图
correlation_matrix = df[numeric_cols].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()
# Out:
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 20844 (\N{CJK UNIFIED IDEOGRAPH-516C}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 24320 (\N{CJK UNIFIED IDEOGRAPH-5F00}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 21578 (\N{CJK UNIFIED IDEOGRAPH-544A}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 26435 (\N{CJK UNIFIED IDEOGRAPH-6743}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 21033 (\N{CJK UNIFIED IDEOGRAPH-5229}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 27714 (\N{CJK UNIFIED IDEOGRAPH-6C42}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 25991 (\N{CJK UNIFIED IDEOGRAPH-6587}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 29486 (\N{CJK UNIFIED IDEOGRAPH-732E}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 39029 (\N{CJK UNIFIED IDEOGRAPH-9875}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 24180 (\N{CJK UNIFIED IDEOGRAPH-5E74}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 20869 (\N{CJK UNIFIED IDEOGRAPH-5185}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 34987 (\N{CJK UNIFIED IDEOGRAPH-88AB}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 24341 (\N{CJK UNIFIED IDEOGRAPH-5F15}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 29992 (\N{CJK UNIFIED IDEOGRAPH-7528}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 27425 (\N{CJK UNIFIED IDEOGRAPH-6B21}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 19987 (\N{CJK UNIFIED IDEOGRAPH-4E13}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 35785 (\N{CJK UNIFIED IDEOGRAPH-8BC9}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 35772 (\N{CJK UNIFIED IDEOGRAPH-8BBC}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 26696 (\N{CJK UNIFIED IDEOGRAPH-6848}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 20214 (\N{CJK UNIFIED IDEOGRAPH-4EF6}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 20215 (\N{CJK UNIFIED IDEOGRAPH-4EF7}) missing from current font.
#   fig.canvas.draw()
# D:\python\lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   fig.canvas.draw()

# %%
df.to_excel("./Data/datapro2.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 df.to_excel("./Data/datapro2.xlsx",index=False)
#
# File D:\python\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\python\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File D:\python\lib\site-packages\pandas\core\generic.py:2373, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2360 from pandas.io.formats.excel import ExcelFormatter
#    2362 formatter = ExcelFormatter(
#    2363     df,
#    2364     na_rep=na_rep,
#    (...)
#    2371     inf_rep=inf_rep,
#    2372 )
# -> 2373 formatter.write(
#    2374     excel_writer,
#    2375     sheet_name=sheet_name,
#    2376     startrow=startrow,
#    2377     startcol=startcol,
#    2378     freeze_panes=freeze_panes,
#    2379     engine=engine,
#    2380     storage_options=storage_options,
#    2381 )
#
# File D:\python\lib\site-packages\pandas\io\formats\excel.py:911, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     907     need_save = False
#     908 else:
#     909     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     910     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 911     writer = ExcelWriter(  # type: ignore[abstract]
#     912         writer, engine=engine, storage_options=storage_options
#     913     )
#     914     need_save = True
#     916 try:
#
# File D:\python\lib\site-packages\pandas\io\excel\_openpyxl.py:60, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      56 from openpyxl.workbook import Workbook
#      58 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 60 super().__init__(
#      61     path,
#      62     mode=mode,
#      63     storage_options=storage_options,
#      64     if_sheet_exists=if_sheet_exists,
#      65     engine_kwargs=engine_kwargs,
#      66 )
#      68 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      69 # the file and later write to it
#      70 if "r+" in self._mode:  # Load from existing workbook
#
# File D:\python\lib\site-packages\pandas\io\excel\_base.py:1302, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1298 self._handles = IOHandles(
#    1299     cast(IO[bytes], path), compression={"compression": None}
#    1300 )
#    1301 if not isinstance(path, ExcelWriter):
# -> 1302     self._handles = get_handle(
#    1303         path, mode, storage_options=storage_options, is_text=False
#    1304     )
#    1305 self._cur_sheet = None
#    1307 if date_format is None:
#
# File D:\python\lib\site-packages\pandas\io\common.py:866, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#    (...)
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
# --> 866         handle = open(handle, ioargs.mode)
#     867     handles.append(handle)
#     869 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: './Data/datapro2.xlsx'

# %%
df.to_csv("./Data/datapro2.CSV",index=False)
